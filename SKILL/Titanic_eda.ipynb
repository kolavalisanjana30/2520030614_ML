# %% [markdown]
# <a href="https://colab.research.google.com/github/kolavalisanjana30/2520030614_ML/blob/main/SKILL/Titanic_eda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
import pandas as pd
import numpy as np
import sklearn
import matplotlib
import seaborn as sns

print("Library Versions")
print("-" * 40)
print(f"Pandas         : {pd.__version__}")
print(f"NumPy          : {np.__version__}")
print(f"Scikit-learn   : {sklearn.__version__}")
print(f"Matplotlib     : {matplotlib.__version__}")
print(f"Seaborn        : {sns.__version__}")
# Out:
# Library Versions
# ----------------------------------------
# Pandas         : 2.2.2
# NumPy          : 2.0.2
# Scikit-learn   : 1.6.1
# Matplotlib     : 3.10.0
# Seaborn        : 0.13.2

# %%
import pandas as pd
import seaborn as sns
from pandas import read_csv
df=read_csv('/content/Titanic-Dataset.csv')

# %%
#Displays the last five records of the dataset.
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4))
plt.boxplot(df['Age'].dropna())
plt.title("Box Plot of Age")
plt.ylabel("Age")
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.boxplot(df['Fare'])
plt.title("Box Plot of Fare")
plt.ylabel("Fare")
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(df['Age'].dropna(), bins=20)
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(8,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()

# %%
import matplotlib.pyplot as plt

features = ["Survived", "Pclass", "Age", "SibSp", "Parch", "Fare"]

df[features].hist(
    bins=20,
    figsize=(15,8)
)

plt.tight_layout()
plt.show()
